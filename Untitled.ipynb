# %%
n=int(input())
temp=n
rem=0
arm=0
while n>0:
    rem=n%10
    n=n//10
    arm=arm+(rem**3)
if arm==temp:
    print(arm,"is armstrong number")
else:
    print(arm,"is not armstrong number")
# Out:
#  153
# 153
# 153 is armstrong number

# %%
lst=list(map(int,input().split()))
first=second=lst[0]
for ele in lst:
    if ele>lst:
        second=first
        first=ele
    elif ele>second and ele!=first:
        second=ele
    print (second if second!=first else -1)
# Out:
#  4 2 7 2 4 9 7
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 4
#       2 first=second=lst[0]
#       3 for ele in lst:
# ----> 4     if ele>lst:
#       5         second=first
#       6         first=ele
#
# TypeError: '>' not supported between instances of 'int' and 'list'
