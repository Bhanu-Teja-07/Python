# %%
import math
from abc import ABC,abstractmethod
class shape(ABC):
    @abstractmethod
    def area(self):
        pass
    @abstractmethod
    def perimeter(self):
        pass
class square(shape):
    def __init__(self,side):
        self.side=side
    def area(self):
        return self.side*self.side
    def perimeter(self):
        return 4*self.side
class rectangle(shape):
    def __init__(self,length,breadth):
        self.length=length
        self.breadth=breadth
    def area(self):
        return self.length*self.breadth
    def perimeter(self):
        return 2*(self.length+self.breadth)
class triangle(shape):
    def __init__(self,base,height):
        self.base=base
        self.height=height
    def area(self):
        return 1/2*self.base*self.height
class circle(shape):
    def __init__(self,radius):
        self.radius=radius
    def area(self):
        return math.pi*self.radius**2
    def perimeter(self):
        return 2*math.pi*self.radius
        
a=square(15)
b=rectangle(10,5)
c=triangle(10,5)
d=circle(6)
print("area of the square =",a.area())
print("perimeter of the square =",a.perimeter())
print(b.area())
print(b.perimeter())
print(c.area())
print(d.area())
print(d.perimeter())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 41
#      39 a=square(15)
#      40 b=rectangle(10,5)
# ---> 41 c=triangle(10,5)
#      42 d=circle(6)
#      43 print("area of the square =",a.area())
#
# TypeError: Can't instantiate abstract class triangle with abstract method perimeter

# %%
from abc import ABC,abstractmethod

class shape(ABC):
    @abstractmethod
    def volume(self):
        pass
    @abstractmethod
    def perimeter(self):
        pass

class cube(shape):
    def __init__(self, side):
        self.side = side
    def volume(self):
        return self.side ** 3
    def perimeter(self):
        return 6 * self.side ** 2   # surface area

class cylinder(shape):
    def __init__(self, radius, height):
        self.radius = radius
        self.height = height
    def volume(self):
        return 3.14 * self.radius**2 * self.height
    def perimeter(self):
        return 2 * 3.14 * self.radius * (self.radius + self.height)  # surface area

class cone(shape):
    def __init__(self, radius, height):
        self.radius = radius
        self.height = height
        self.slant = (radius**2 + height**2) ** 0.5
    def volume(self):
        return (1/3) * 3.14 * self.radius**2 * self.height
    def perimeter(self):
        return 3.14 * self.radius * (self.radius + self.slant)  # surface area

class cuboid(shape):
    def __init__(self, length, width, height):
        self.length = length
        self.width = width
        self.height = height
    def volume(self):
        return self.length * self.width * self.height
    def perimeter(self):
        return 2*(self.length*self.width + self.width*self.height + self.height*self.length)

cyl = cylinder(3, 5)
print("Cylinder Volume:", cyl.volume())
print("Cylinder Surface Area:", cyl.perimeter())

con = cone(3, 4)
print("Cone Volume:", con.volume())
print("Cone Surface Area:", con.perimeter())

cub = cuboid(2, 3, 4)
print("Cuboid Volume:", cub.volume())
print("Cuboid Surface Area:", cub.perimeter())
# Out:
# Cylinder Volume: 141.3
# Cylinder Surface Area: 150.72
# Cone Volume: 37.68
# Cone Surface Area: 75.36
# Cuboid Volume: 24
# Cuboid Surface Area: 52
