# %%
d={"name":"Bhanu Teja",'batch':49,"course":"Python"}
print(d)
# Out:
# {'name': 'Bhanu Teja', 'batch': 49, 'course': 'python'}

# %%
d={"name": "Bhanu Teja", "batch":49, "course": "Python", "course": "Python and Java"}
print(d['course'])
d["batch"]=50
print(d)
# Out:
# Python and Java
# {'name': 'Bhanu Teja', 'batch': 50, 'course': 'Python and Java'}

# %%
d={"name": "Bhanu Teja", "batch":49, "course": "Python", "course": "Python and Java"}
d["batch"]=50
print(d.get("location","india"))
print(d.get("name"))
print(d.get("marks"))
# Out:
# india
# Bhanu Teja
# None

# %%
d={"name": "Bhanu Teja", "batch":49, "course": "Python", "course": "Python and Java"}
new_d={"course":"java", "location":"Hyderabad","marks":95}
d.update(new_d)
print(d)
print(d.keys())
print(d.values())
print(d.items())
print(list(d.items()))
print(type(d.items()))
d.pop("marks")
print(d)
d.popitem()
print(d)
print(len(d))
# Out:
# {'name': 'Bhanu Teja', 'batch': 49, 'course': 'java', 'location': 'Hyderabad', 'marks': 95}
# dict_keys(['name', 'batch', 'course', 'location', 'marks'])
# dict_values(['Bhanu Teja', 49, 'java', 'Hyderabad', 95])
# dict_items([('name', 'Bhanu Teja'), ('batch', 49), ('course', 'java'), ('location', 'Hyderabad'), ('marks', 95)])
# [('name', 'Bhanu Teja'), ('batch', 49), ('course', 'java'), ('location', 'Hyderabad'), ('marks', 95)]
# <class 'dict_items'>
# {'name': 'Bhanu Teja', 'batch': 49, 'course': 'java', 'location': 'Hyderabad'}
# {'name': 'Bhanu Teja', 'batch': 49, 'course': 'java'}
# 3
